# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai
from google.colab import userdata

from IPython.display import Markdown, display
def to_markdown(text):
  text = text.replace('.','*')
  return Markdown(textwrap.indent(text, '> ',predicate=lambda _:True))

# %%
import os
os.environ['GOOGLE_API_KEY'] = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'

# %%
genai.configure(api_key="XXXXXXXXXXXXXXXXXXXXXXXXXXXX")

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("who is dhoni")
# Out:
# CPU times: user 117 ms, sys: 16.4 ms, total: 133 ms
# Wall time: 8.28 s

# %%
to_markdown(response.text)
# Out:
# > Mahendra Singh Dhoni (born 7 July 1981) is a former Indian international cricketer who captained the Indian national team in limited-overs formats from 2007 to 2016 and in Test cricket from 2008 to 2014* A wicket-keeper batter, he is widely regarded as one of the greatest captains in the history of cricket*
# >
# > Dhoni is the most successful captain in the history of Indian cricket, having led the team to two World Cups (2007 ICC World Twenty20 and 2011 Cricket World Cup), the 2013 ICC Champions Trophy, and the 2010 and 2016 Asia Cups* He is also the only captain to have won all three ICC trophies*
# >
# > After retiring from international cricket in 2019, Dhoni has been the captain of the Chennai Super Kings in the Indian Premier League (IPL)* He led the team to four IPL titles in 2010, 2011, 2018, and 2021*
# >
# ...

# %%
response.prompt_feedback

# %%
import PIL.Image
img = PIL.Image.open('/content/catoo.jfif')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x148>

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# > This is a tabby cat with green eyes* It is looking directly at the camera* The cat has a white patch on its chest* The background is blurry, but it appears to be outdoors*

# %%
response = model.generate_content(["write a short note on this image. it shouls include discription of photo",img],stream=True)
response.resolve()
to_markdown(response.text)
# Out:
# > The photo shows a tabby cat with green eyes staring intently at the camera* The cat has a white patch on its chest and is sitting on a patio* The background is blurred, suggesting the photo was taken outside on a sunny day* The cat's expression is alert and curious, and its fur is sleek and healthy*
